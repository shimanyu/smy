# %%
import numpy as np

# %%
a=[1,2,3,4]
b=np.array(a)
print(b)
display(b)
print(type(b))
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])
# <class 'numpy.ndarray'>

# %%
a=[1,1.0,'s']
b=np.array(a)
disppay(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-668e756de893> in <module>()
#       1 a=[1,1.0,'s']
#       2 b=np.array(a)
# ----> 3 disppay(b)
#
# NameError: name 'disppay' is not defined

# %%
a=[1,1.0,'s']
b=np.array(a)
disppay(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-668e756de893> in <module>()
#       1 a=[1,1.0,'s']
#       2 b=np.array(a)
# ----> 3 disppay(b)
#
# NameError: name 'disppay' is not defined

# %%
a=[1,1.0,'s']
b=np.array(a)
display(b)
# Out:
# array(['1', '1.0', 's'], dtype='<U32')

# %%
c=[[1,2],[3,4]]
d=np.array(c)
display(d)
display(d.shape)
# Out:
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
d
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
display(b.shape)
display(d.shape)
# Out:
# (3,)
# (2, 2)

# %%
b
# Out:
# array(['1', '1.0', 's'], dtype='<U32')

# %%
display(b.shape)
display(d.shape)
# Out:
# (3,)
# (2, 2)

# %%
display(b.size)
display(d.size)
# Out:
# 3
# 4

# %%
display(b.dtype)
display(d.dtype)
# Out:
# dtype('<U32')
# dtype('int32')

# %%
joker=[1,2,3,4]
huwang=[1.1,1.2,1.3]
joker_array=np.array(joker)
huwang_array=np.array(huwang)
display(joker_array.dtype,huwang_array.dtype)
# Out:
# dtype('int32')
# dtype('float64')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weixin=plt.imread('C:\\Users\\Administrator\\Pictures\\weixin.jpg')
display(weixin)
# Out:
# array([[[37, 26, 22],
#         [37, 26, 22],
#         [39, 28, 24],
#         ...,
#         [24, 20, 11],
#         [24, 20, 11],
#         [23, 19, 10]],
#
#        [[33, 22, 18],
#         [38, 27, 23],
#         [38, 27, 23],
#         ...,
#         [33, 29, 20],
#         [32, 28, 19],
#         [28, 24, 15]],
#
#        [[33, 22, 18],
#         [33, 22, 18],
#         [33, 22, 18],
#         ...,
#         [43, 39, 30],
#         [42, 38, 29],
#         [39, 35, 26]],
#
#        ...,
#
#        [[ 9,  3,  5],
#         [ 8,  2,  4],
#         [ 6,  0,  2],
#         ...,
#         [18, 10,  7],
#         [18,  8,  6],
#         [17,  7,  5]],
#
#        [[ 9,  3,  5],
#         [ 6,  0,  2],
#         [ 7,  1,  3],
#         ...,
#         [23, 15, 12],
#         [27, 17, 15],
#         [28, 18, 16]],
#
#        [[ 7,  1,  3],
#         [ 5,  0,  1],
#         [ 7,  1,  3],
#         ...,
#         [27, 19, 16],
#         [32, 22, 20],
#         [33, 23, 21]]], dtype=uint8)

# %%
plt.imshow(weixin)

# %%
weixin_change=weixin.copy()

# %%
weixin_change.shape
# Out:
# (4160, 3120, 3)

# %%
for i in range(100):
     for j in range(60):
        for k in range(3):
            if weixin_change[i][j][k]==4050:
                weixin_change[i][j][k]=2

# %%
weixin_change
# Out:
# array([[[37, 26, 22],
#         [37, 26, 22],
#         [39, 28, 24],
#         ...,
#         [24, 20, 11],
#         [24, 20, 11],
#         [23, 19, 10]],
#
#        [[33, 22, 18],
#         [38, 27, 23],
#         [38, 27, 23],
#         ...,
#         [33, 29, 20],
#         [32, 28, 19],
#         [28, 24, 15]],
#
#        [[33, 22, 18],
#         [33, 22, 18],
#         [33, 22, 18],
#         ...,
#         [43, 39, 30],
#         [42, 38, 29],
#         [39, 35, 26]],
#
#        ...,
#
#        [[ 9,  3,  5],
#         [ 8,  2,  4],
#         [ 6,  0,  2],
#         ...,
#         [18, 10,  7],
#         [18,  8,  6],
#         [17,  7,  5]],
#
#        [[ 9,  3,  5],
#         [ 6,  0,  2],
#         [ 7,  1,  3],
#         ...,
#         [23, 15, 12],
#         [27, 17, 15],
#         [28, 18, 16]],
#
#        [[ 7,  1,  3],
#         [ 5,  0,  1],
#         [ 7,  1,  3],
#         ...,
#         [27, 19, 16],
#         [32, 22, 20],
#         [33, 23, 21]]], dtype=uint8)

# %%
plt.imshow(weixin_change)
